# %% [markdown]
# # Flower Recognition CNN Keras

# %%
import os
print(os.listdir('D:/Python3.7/flowers'))
# Out:
# ['daisy', 'dandelion', 'rose', 'sunflower', 'tulip']

# %% [markdown]
# <a id="content1"></a>
# ## 1 ) Importing Various Modules.

# %%
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
 
# %matplotlib inline  
style.use('fivethirtyeight')
sns.set(style='whitegrid',color_codes=True)

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,roc_curve,roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder

from keras.preprocessing.image import ImageDataGenerator

from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop
from tensorflow.keras.utils import to_categorical

from keras.layers import Dropout, Flatten,Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
 
import tensorflow as tf
import random as rn

import cv2                  
import numpy as np  
from tqdm import tqdm
import os                   
from random import shuffle  
from zipfile import ZipFile
from PIL import Image

# %% [markdown]
# <a id="content2"></a>
# ## 2 ) Preparing the Data

# %%
X=[]
Z=[]
IMG_SIZE=150
FLOWER_DAISY_DIR='D:/Python3.7/flowers/daisy'
FLOWER_SUNFLOWER_DIR='D:/Python3.7/flowers/sunflower'
FLOWER_TULIP_DIR='D:/Python3.7/flowers/tulip'
FLOWER_DANDI_DIR='D:/Python3.7/flowers/dandelion'
FLOWER_ROSE_DIR='D:/Python3.7/flowers/rose'

# %%
def assign_label(img,flower_type):
    return flower_type

# %%
def make_train_data(flower_type,DIR):
    for img in tqdm(os.listdir(DIR)):
        label=assign_label(img,flower_type)
        path = os.path.join(DIR,img)
        img = cv2.imread(path,cv2.IMREAD_COLOR)
        img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))
        
        X.append(np.array(img))
        Z.append(str(label))

# %%
make_train_data('Daisy',FLOWER_DAISY_DIR)
print(len(X))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 764/764 [00:01<00:00, 669.33it/s]
# 764

# %%
make_train_data('Sunflower',FLOWER_SUNFLOWER_DIR)
print(len(X))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 733/733 [00:05<00:00, 141.09it/s]
# 1497

# %%
make_train_data('Tulip',FLOWER_TULIP_DIR)
print(len(X))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 982/982 [00:06<00:00, 147.41it/s]
# 2479

# %%
make_train_data('Dandelion',FLOWER_DANDI_DIR)
print(len(X))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1052/1052 [00:01<00:00, 633.88it/s]
# 3531

# %%
make_train_data('Rose',FLOWER_ROSE_DIR)
print(len(X))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 784/784 [00:03<00:00, 228.89it/s]
# 4315

# %% [markdown]
# ## 2.1) Visualizing some Random Images

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=rn.randint(0,len(Z))
        ax[i,j].imshow(X[l])
        ax[i,j].set_title('Flower: '+Z[l])
        
plt.tight_layout()

# %% [markdown]
# ## 2.2 ) Label Encoding the Y array (i.e. Daisy->0, Rose->1 etc...)

# %%
le=LabelEncoder()
Y=le.fit_transform(Z)
Y=to_categorical(Y,5)
X=np.array(X)
X=X/255

# %% [markdown]
# ## 2.3 ) Splitting into Training and Validation Sets

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=42)

# %% [markdown]
# ## 2.4 ) Setting the Random Seeds

# %%
np.random.seed(42)
rn.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# <a id="content3"></a>
# ## 3 ) Modelling

# %% [markdown]
# ## 3.1 ) Building the ConvNet Model

# %%
model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',activation ='relu', input_shape = (150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
 

model.add(Conv2D(filters =96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Conv2D(filters = 96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(5, activation = "softmax"))

# %% [markdown]
# ## 3.2 ) Using a LR Annealer

# %%
batch_size=128
epochs=50

from keras.callbacks import ReduceLROnPlateau
red_lr= ReduceLROnPlateau(monitor='val_acc',patience=3,verbose=1,factor=0.1)

# %% [markdown]
# ## 3.3 ) Data Augmentation to prevent Overfitting

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(x_train)

# %% [markdown]
# ## 3.4 ) Compiling the Keras Model & Summary

# %%
model.compile(optimizer=Adam(lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      2432
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 96)        55392
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 96)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 96)        83040
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 96)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 7776)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3981824
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 2565
# =================================================================
# Total params: 4,143,749
# Trainable params: 4,143,749
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3.5 ) Fitting on the Training set and making predcitons on the Validation set

# %%
History = model.fit_generator(datagen.flow(x_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test,y_test),
                              verbose = 1, steps_per_epoch=x_train.shape[0] // batch_size)
# model.fit(x_train,y_train,epochs=epochs,batch_size=batch_size,validation_data = (x_test,y_test))
# Out:
# Epoch 1/50
# 25/25 [==============================] - 51s 2s/step - loss: 1.4497 - accuracy: 0.3459 - val_loss: 1.2539 - val_accuracy: 0.4782
# Epoch 2/50
# 25/25 [==============================] - 52s 2s/step - loss: 1.1868 - accuracy: 0.5010 - val_loss: 1.0830 - val_accuracy: 0.5700
# Epoch 3/50
# 25/25 [==============================] - 52s 2s/step - loss: 1.1046 - accuracy: 0.5483 - val_loss: 0.9784 - val_accuracy: 0.6145
# Epoch 4/50
# 25/25 [==============================] - 51s 2s/step - loss: 1.0176 - accuracy: 0.6010 - val_loss: 0.9788 - val_accuracy: 0.5996
# Epoch 5/50
# 25/25 [==============================] - 52s 2s/step - loss: 0.9574 - accuracy: 0.6216 - val_loss: 0.9389 - val_accuracy: 0.6209
# Epoch 6/50
# 25/25 [==============================] - 51s 2s/step - loss: 0.9254 - accuracy: 0.6406 - val_loss: 0.9293 - val_accuracy: 0.6182
# Epoch 7/50
# 25/25 [==============================] - 52s 2s/step - loss: 0.9020 - accuracy: 0.6499 - val_loss: 0.8674 - val_accuracy: 0.6525
# Epoch 8/50
# 25/25 [==============================] - 53s 2s/step - loss: 0.8623 - accuracy: 0.6647 - val_loss: 0.8021 - val_accuracy: 0.6654
# Epoch 9/50
# 25/25 [==============================] - 52s 2s/step - loss: 0.8281 - accuracy: 0.6782 - val_loss: 0.7547 - val_accuracy: 0.6988
# Epoch 10/50
# 25/25 [==============================] - 51s 2s/step - loss: 0.8089 - accuracy: 0.6850 - val_loss: 0.8008 - val_accuracy: 0.6803
# Epoch 11/50
# 25/25 [==============================] - 52s 2s/step - loss: 0.8028 - accuracy: 0.7006 - val_loss: 0.8197 - val_accuracy: 0.6830
# Epoch 12/50
# 25/25 [==============================] - 51s 2s/step - loss: 0.7696 - accuracy: 0.6972 - val_loss: 0.7455 - val_accuracy: 0.7164
# Epoch 13/50
# 25/25 [==============================] - 51s 2s/step - loss: 0.7487 - accuracy: 0.7178 - val_loss: 0.7337 - val_accuracy: 0.7164
# Epoch 14/50
# 25/25 [==============================] - 52s 2s/step - loss: 0.7215 - accuracy: 0.7233 - val_loss: 0.6942 - val_accuracy: 0.7266
# Epoch 15/50
# 25/25 [==============================] - 52s 2s/step - loss: 0.6918 - accuracy: 0.7378 - val_loss: 0.6873 - val_accuracy: 0.7312
# Epoch 16/50
# 25/25 [==============================] - 51s 2s/step - loss: 0.6949 - accuracy: 0.7342 - val_loss: 0.6625 - val_accuracy: 0.7498
# Epoch 17/50
# 25/25 [==============================] - 52s 2s/step - loss: 0.6773 - accuracy: 0.7445 - val_loss: 0.6572 - val_accuracy: 0.7405
# Epoch 18/50
# 25/25 [==============================] - 53s 2s/step - loss: 0.6282 - accuracy: 0.7575 - val_loss: 0.7489 - val_accuracy: 0.7220
# Epoch 19/50
# 25/25 [==============================] - 53s 2s/step - loss: 0.6468 - accuracy: 0.7506 - val_loss: 0.6624 - val_accuracy: 0.7498
# Epoch 20/50
# 25/25 [==============================] - 52s 2s/step - loss: 0.6544 - accuracy: 0.7555 - val_loss: 0.7695 - val_accuracy: 0.7071
# Epoch 21/50
# 25/25 [==============================] - 53s 2s/step - loss: 0.6209 - accuracy: 0.7664 - val_loss: 0.6377 - val_accuracy: 0.7665
# Epoch 22/50
# 25/25 [==============================] - 51s 2s/step - loss: 0.5736 - accuracy: 0.7796 - val_loss: 0.6405 - val_accuracy: 0.7627
# Epoch 23/50
# 25/25 [==============================] - 50s 2s/step - loss: 0.5656 - accuracy: 0.7838 - val_loss: 0.6040 - val_accuracy: 0.7748
# Epoch 24/50
# 25/25 [==============================] - 55s 2s/step - loss: 0.5648 - accuracy: 0.7941 - val_loss: 0.6273 - val_accuracy: 0.7488
# Epoch 25/50
# 25/25 [==============================] - 54s 2s/step - loss: 0.5615 - accuracy: 0.7857 - val_loss: 0.6130 - val_accuracy: 0.7702
# Epoch 26/50
# 25/25 [==============================] - 51s 2s/step - loss: 0.5631 - accuracy: 0.7880 - val_loss: 0.6510 - val_accuracy: 0.7627
# Epoch 27/50
# 25/25 [==============================] - 50s 2s/step - loss: 0.5360 - accuracy: 0.7979 - val_loss: 0.6016 - val_accuracy: 0.7739
# Epoch 28/50
# 25/25 [==============================] - 50s 2s/step - loss: 0.5107 - accuracy: 0.8089 - val_loss: 0.6837 - val_accuracy: 0.7442
# Epoch 29/50
# 25/25 [==============================] - 50s 2s/step - loss: 0.5205 - accuracy: 0.8060 - val_loss: 0.6197 - val_accuracy: 0.7674
# Epoch 30/50
# 25/25 [==============================] - 49s 2s/step - loss: 0.4781 - accuracy: 0.8211 - val_loss: 0.6349 - val_accuracy: 0.7878
# Epoch 31/50
# 25/25 [==============================] - 51s 2s/step - loss: 0.4643 - accuracy: 0.8288 - val_loss: 0.5787 - val_accuracy: 0.7850
# Epoch 32/50
# 25/25 [==============================] - 50s 2s/step - loss: 0.4409 - accuracy: 0.8391 - val_loss: 0.5862 - val_accuracy: 0.7822
# Epoch 33/50
# 25/25 [==============================] - 50s 2s/step - loss: 0.4474 - accuracy: 0.8375 - val_loss: 0.5643 - val_accuracy: 0.7887
# Epoch 34/50
# 25/25 [==============================] - 51s 2s/step - loss: 0.4382 - accuracy: 0.8436 - val_loss: 0.6124 - val_accuracy: 0.7859
# Epoch 35/50
# 25/25 [==============================] - 49s 2s/step - loss: 0.4497 - accuracy: 0.8317 - val_loss: 0.5768 - val_accuracy: 0.7841
# Epoch 36/50
# 25/25 [==============================] - 49s 2s/step - loss: 0.4094 - accuracy: 0.8456 - val_loss: 0.6625 - val_accuracy: 0.7794
# Epoch 37/50
# 25/25 [==============================] - 50s 2s/step - loss: 0.4235 - accuracy: 0.8353 - val_loss: 0.6185 - val_accuracy: 0.7933
# Epoch 38/50
# 25/25 [==============================] - 51s 2s/step - loss: 0.4260 - accuracy: 0.8420 - val_loss: 0.6180 - val_accuracy: 0.7905
# Epoch 39/50
# 25/25 [==============================] - 50s 2s/step - loss: 0.4323 - accuracy: 0.8391 - val_loss: 0.5631 - val_accuracy: 0.7961
# Epoch 40/50
# 25/25 [==============================] - 49s 2s/step - loss: 0.3637 - accuracy: 0.8584 - val_loss: 0.5830 - val_accuracy: 0.7943
# Epoch 41/50
# 25/25 [==============================] - 49s 2s/step - loss: 0.3494 - accuracy: 0.8710 - val_loss: 0.6015 - val_accuracy: 0.8007
# Epoch 42/50
# 25/25 [==============================] - 52s 2s/step - loss: 0.3790 - accuracy: 0.8616 - val_loss: 0.5871 - val_accuracy: 0.7989
# Epoch 43/50
# 25/25 [==============================] - 52s 2s/step - loss: 0.3460 - accuracy: 0.8681 - val_loss: 0.6081 - val_accuracy: 0.7896
# Epoch 44/50
# 25/25 [==============================] - 50s 2s/step - loss: 0.3709 - accuracy: 0.8684 - val_loss: 0.6449 - val_accuracy: 0.7868
# Epoch 45/50
# 25/25 [==============================] - 49s 2s/step - loss: 0.3447 - accuracy: 0.8771 - val_loss: 0.5971 - val_accuracy: 0.7952
# Epoch 46/50
# 25/25 [==============================] - 51s 2s/step - loss: 0.3192 - accuracy: 0.8829 - val_loss: 0.6170 - val_accuracy: 0.8044
# Epoch 47/50
# 25/25 [==============================] - 50s 2s/step - loss: 0.2958 - accuracy: 0.8906 - val_loss: 0.6128 - val_accuracy: 0.8119
# Epoch 48/50
# 25/25 [==============================] - 50s 2s/step - loss: 0.3073 - accuracy: 0.8855 - val_loss: 0.6249 - val_accuracy: 0.7952
# Epoch 49/50
# 25/25 [==============================] - 50s 2s/step - loss: 0.3349 - accuracy: 0.8723 - val_loss: 0.6722 - val_accuracy: 0.8109
# Epoch 50/50
# 25/25 [==============================] - 50s 2s/step - loss: 0.3017 - accuracy: 0.8859 - val_loss: 0.6467 - val_accuracy: 0.8109

# %% [markdown]
# <a id="content4"></a>
# ## 4 ) Evaluating the Model Performance

# %%
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
plt.plot(History.history['accuracy'])
plt.plot(History.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %% [markdown]
# <a id="content5"></a>
# ## 5 ) Visualizing Predictons on the Validation Set

# %%
# getting predictions on val set.
pred=model.predict(x_test)
pred_digits=np.argmax(pred,axis=1)

# %%
# now storing some properly as well as misclassified indexes'.
i=0
prop_class=[]
mis_class=[]

for i in range(len(y_test)):
    if(np.argmax(y_test[i])==pred_digits[i]):
        prop_class.append(i)
    if(len(prop_class)==8):
        break

i=0
for i in range(len(y_test)):
    if(not np.argmax(y_test[i])==pred_digits[i]):
        mis_class.append(i)
    if(len(mis_class)==8):
        break

# %% [markdown]
# #### CORRECTLY CLASSIFIED FLOWER IMAGES

# %%
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

count=0
fig,ax=plt.subplots(4,2)
fig.set_size_inches(15,15)
for i in range (4):
    for j in range (2):
        ax[i,j].imshow(x_test[prop_class[count]])
        ax[i,j].set_title("Predicted Flower :"+str(le.inverse_transform([pred_digits[prop_class[count]]]))+"\n"+"Actual Flower : "+str(le.inverse_transform([np.argmax(y_test[prop_class[count]])]))) 
        plt.tight_layout()
        count+=1
